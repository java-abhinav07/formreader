# %%
# %cd drive/My Drive/IITB_Assignment/
# Out:
# /content/drive/My Drive/IITB_Assignment

# %%
# !git clone https://java-abhinav07:/java-abhinav07/abhinav_java_9873155323-IITB-Assignment-Jul-Dec2020-Batch2.git
# Out:
# Cloning into 'abhinav_java_9873155323-IITB-Assignment-Jul-Dec2020-Batch2'...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 703 (delta 5), reused 86 (delta 5), pack-reused 616
# Receiving objects: 100% (703/703), 19.56 MiB | 12.09 MiB/s, done.
# Resolving deltas: 100% (368/368), done.
# Checking out files: 100% (141/141), done.

# %%
# %cd abhinav_java_9873155323-IITB-Assignment-Jul-Dec2020-Batch2/attention-ocr/
# Out:
# /content/drive/My Drive/IITB_Assignment/abhinav_java_9873155323-IITB-Assignment-Jul-Dec2020-Batch2/attention-ocr

# %%
#!pip uninstall aocr
# !pip3 install aocr
#!pip3 install -r requirements.txt
# !pip3 install tensorflow-gpu==1.2.1

# %%
# !git pull origin master
# Out:
# From https://github.com/java-abhinav07/abhinav_java_9873155323-IITB-Assignment-Jul-Dec2020-Batch2
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
! aocr train /content/drive/My\ Drive/IITB_Assignment/datasets/training.tfrecords --max-prediction 51
# Out:
# Streaming output truncated to the last 5000 lines.
# 2020-08-24 19:13:43,512 root  INFO     Step 9419: 0.624s, loss: 0.005836, perplexity: 1.005853.
# 2020-08-24 19:13:44,203 root  INFO     Step 9420: 0.634s, loss: 0.002201, perplexity: 1.002203.
# 2020-08-24 19:13:44,918 root  INFO     Step 9421: 0.639s, loss: 0.000406, perplexity: 1.000406.
# 2020-08-24 19:13:45,616 root  INFO     Step 9422: 0.627s, loss: 0.000490, perplexity: 1.000491.
# 2020-08-24 19:13:46,302 root  INFO     Step 9423: 0.629s, loss: 0.001241, perplexity: 1.001242.
# 2020-08-24 19:13:47,016 root  INFO     Step 9424: 0.638s, loss: 0.000825, perplexity: 1.000825.
# 2020-08-24 19:13:47,700 root  INFO     Step 9425: 0.634s, loss: 0.000492, perplexity: 1.000492.
# 2020-08-24 19:13:48,398 root  INFO     Step 9426: 0.641s, loss: 0.009237, perplexity: 1.009280.
# 2020-08-24 19:13:49,089 root  INFO     Step 9427: 0.623s, loss: 0.015181, perplexity: 1.015297.
# ...

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install protobuf
