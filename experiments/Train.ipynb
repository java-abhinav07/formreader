# %% [markdown]
# ###Install AOCR from git repository

# %%
# !ls
# %cd drive/My\ Drive/IITB_Assignment/
# ! python -m pip uninstall git+https://java-abhinav07:ajfooty0799@github.com/java-abhinav07/abhinav_java_9873155323-IITB-Assignment-Jul-Dec2020-Batch2.git
! python -m pip install git+https://java-abhinav07:@github.com/java-abhinav07/abhinav_java_9873155323-IITB-Assignment-Jul-Dec2020-Batch2.git --upgrade
# %cd abhinav_java_9873155323-IITB-Assignment-Jul-Dec2020-Batch2.git

# %% [markdown]
# ###Start the training process for aocr

# %%
# %tensorflow_version 1.x

# %%
# output removed, kindly refer logs for details
! aocr train /content/drive/My\ Drive/IITB_Assignment/datasets/alphanumeric_AZ09/training.tfrecords

# %% [markdown]
# ###Test the best model on testing data

# %%
! aocr test /content/drive/My\ Drive/IITB_Assignment/datasets/alphanumeric_AZ09/testing.tfrecords
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/aocr/__main__.py:20: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/aocr/__main__.py:20: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
#
# 2020-08-25 17:34:01.909120: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-08-25 17:34:01.909383: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x12d8f40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-25 17:34:01.909423: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-25 17:34:01.911556: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %% [markdown]
# ###Install modified AOCR from git repository
